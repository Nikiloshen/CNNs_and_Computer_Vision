# %%
from ultralytics import YOLO

model = YOLO('yolov8x')

result = model.predict('input_videos/input_video.mp4', save=True)
print(result)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.187013626098633, 'inference': 12.264013290405273, 'postprocess': 1.3167858123779297}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  27],
#         [ 19,  11,  26],
#         [ 12,   3,  21],
#         ...,
#         [ 17,   2,  45],
#         [ 17,   3,  42],
#         [ 17,   3,  42]],
#
#        [[ 20,  12,  27],
#         [ 18,  10,  25],
#         [ 12,   3,  21],
#         ...,
#         [ 25,  10,  53],
#         [ 26,  12,  51],
#         [ 25,  11,  50]],
#
#        [[ 21,  11,  31],
#         [ 21,  11,  31],
#         [ 19,   8,  31],
#         ...,
#         [ 32,  18,  57],
#         [ 34,  18,  55],
#         [ 35,  19,  56]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1545886993408203, 'inference': 12.275934219360352, 'postprocess': 1.3196468353271484}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   2,  45],
#         [ 17,   3,  42],
#         [ 17,   3,  42]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,  10,  53],
#         [ 26,  12,  51],
#         [ 25,  11,  50]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  57],
#         [ 34,  18,  55],
#         [ 35,  19,  56]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1657943725585938, 'inference': 12.284517288208008, 'postprocess': 1.3399124145507812}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   2,  45],
#         [ 17,   3,  42],
#         [ 17,   3,  42]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,  10,  53],
#         [ 26,  12,  51],
#         [ 25,  11,  50]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  57],
#         [ 34,  18,  55],
#         [ 35,  19,  56]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [173, 142, 104],
#         [173, 142, 104],
#         [173, 142, 104]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.2351741790771484, 'inference': 12.54129409790039, 'postprocess': 1.4083385467529297}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.2275447845458984, 'inference': 12.387275695800781, 'postprocess': 1.394510269165039}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.231597900390625, 'inference': 12.462854385375977, 'postprocess': 1.3861656188964844}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1398067474365234, 'inference': 12.365579605102539, 'postprocess': 1.3155937194824219}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.401590347290039, 'inference': 12.973308563232422, 'postprocess': 1.338958740234375}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.147674560546875, 'inference': 12.71200180053711, 'postprocess': 1.2984275817871094}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1238327026367188, 'inference': 12.209415435791016, 'postprocess': 1.2898445129394531}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   1,  47],
#         [ 17,   3,  44],
#         [ 17,   3,  44]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   9,  55],
#         [ 26,  12,  53],
#         [ 25,  11,  52]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  18,  59],
#         [ 34,  17,  57],
#         [ 35,  18,  58]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.135753631591797, 'inference': 12.232303619384766, 'postprocess': 1.2860298156738281}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  48],
#         [ 17,   2,  45],
#         [ 17,   2,  45]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   8,  56],
#         [ 26,  11,  54],
#         [ 25,  10,  53]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  17,  60],
#         [ 34,  17,  59],
#         [ 35,  18,  60]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.112865447998047, 'inference': 12.230873107910156, 'postprocess': 1.2919902801513672}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1021366119384766, 'inference': 12.21776008605957, 'postprocess': 1.295328140258789}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.116680145263672, 'inference': 12.20846176147461, 'postprocess': 1.28173828125}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.122640609741211, 'inference': 12.237310409545898, 'postprocess': 1.3041496276855469}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1669864654541016, 'inference': 12.240409851074219, 'postprocess': 1.294851303100586}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.154827117919922, 'inference': 12.261629104614258, 'postprocess': 1.3086795806884766}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.117633819580078, 'inference': 12.288093566894531, 'postprocess': 1.3060569763183594}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 20,  12,  25],
#         [ 19,  11,  24],
#         [ 11,   3,  18],
#         ...,
#         [ 17,   0,  50],
#         [ 17,   1,  47],
#         [ 17,   1,  47]],
#
#        [[ 20,  12,  25],
#         [ 18,  10,  23],
#         [ 11,   3,  18],
#         ...,
#         [ 25,   7,  58],
#         [ 26,  10,  56],
#         [ 25,   9,  55]],
#
#        [[ 21,  12,  30],
#         [ 21,  12,  30],
#         [ 18,   8,  28],
#         ...,
#         [ 32,  16,  62],
#         [ 34,  16,  60],
#         [ 35,  17,  61]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1190643310546875, 'inference': 12.272119522094727, 'postprocess': 1.2981891632080078}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.1903514862060547, 'inference': 12.269735336303711, 'postprocess': 1.3306140899658203}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 16,  11,  23],
#         [ 16,  11,  23],
#         [ 12,   7,  21],
#         ...,
#         [  7,   0,  38],
#         [  9,   0,  39],
#         [ 12,   1,  42]],
#
#        [[ 17,  12,  24],
#         [ 16,  11,  23],
#         [ 11,   6,  20],
#         ...,
#         [ 16,   4,  47],
#         [ 20,   9,  50],
#         [ 21,  10,  51]],
#
#        [[ 20,  14,  31],
#         [ 20,  14,  31],
#         [ 18,  11,  30],
#         ...,
#         [ 30,  19,  60],
#         [ 34,  20,  59],
#         [ 37,  23,  62]],
#
#        ...,
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 150, 110],
#         [180, 150, 110],
#         [180, 150, 110],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.215147018432617, 'inference': 12.355566024780273, 'postprocess': 1.3630390167236328}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 17,  12,  24],
#         [ 17,  12,  24],
#         [ 13,   8,  22],
#         ...,
#         [  7,   0,  38],
#         [  9,   0,  39],
#         [ 12,   1,  42]],
#
#        [[ 17,  12,  24],
#         [ 16,  11,  23],
#         [ 11,   6,  20],
#         ...,
#         [ 16,   4,  47],
#         [ 20,   9,  50],
#         [ 21,  10,  51]],
#
#        [[ 20,  14,  31],
#         [ 20,  14,  31],
#         [ 18,  11,  30],
#         ...,
#         [ 30,  19,  60],
#         [ 34,  20,  59],
#         [ 37,  23,  62]],
#
#        ...,
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.308368682861328, 'inference': 12.547969818115234, 'postprocess': 1.4579296112060547}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 19,  14,  28],
#         [ 17,  12,  26],
#         [ 12,   7,  21],
#         ...,
#         [  7,   0,  38],
#         [  9,   0,  39],
#         [ 12,   1,  42]],
#
#        [[ 18,  13,  27],
#         [ 16,  11,  25],
#         [ 10,   5,  19],
#         ...,
#         [ 16,   4,  47],
#         [ 20,   9,  50],
#         [ 21,  10,  51]],
#
#        [[ 19,  12,  31],
#         [ 19,  12,  31],
#         [ 17,  10,  29],
#         ...,
#         [ 30,  19,  60],
#         [ 34,  20,  59],
#         [ 37,  23,  62]],
#
#        ...,
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.3119449615478516, 'inference': 12.420415878295898, 'postprocess': 1.3957023620605469}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 21,  13,  28],
#         [ 19,  11,  26],
#         [ 14,   6,  21],
#         ...,
#         [  7,   0,  38],
#         [  9,   0,  39],
#         [ 12,   1,  42]],
#
#        [[ 20,  12,  27],
#         [ 18,  10,  25],
#         [ 12,   4,  19],
#         ...,
#         [ 16,   4,  47],
#         [ 20,   9,  50],
#         [ 21,  10,  51]],
#
#        [[ 21,  11,  31],
#         [ 21,  11,  31],
#         [ 19,   9,  29],
#         ...,
#         [ 30,  19,  60],
#         [ 34,  20,  59],
#         [ 37,  23,  62]],
#
#        ...,
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.2356510162353516, 'inference': 12.318611145019531, 'postprocess': 1.3554096221923828}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 21,  13,  28],
#         [ 19,  11,  26],
#         [ 14,   6,  21],
#         ...,
#         [  7,   0,  40],
#         [  9,   0,  40],
#         [ 12,   0,  43]],
#
#        [[ 20,  12,  27],
#         [ 18,  10,  25],
#         [ 12,   4,  19],
#         ...,
#         [ 16,   3,  49],
#         [ 20,   8,  51],
#         [ 21,   9,  52]],
#
#        [[ 21,  11,  31],
#         [ 21,  11,  31],
#         [ 19,   9,  29],
#         ...,
#         [ 30,  18,  61],
#         [ 34,  20,  61],
#         [ 37,  23,  64]],
#
#        ...,
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.3283958435058594, 'inference': 13.558626174926758, 'postprocess': 1.4719963073730469}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[ 21,  13,  28],
#         [ 19,  11,  26],
#         [ 14,   6,  21],
#         ...,
#         [  7,   0,  41],
#         [  9,   0,  42],
#         [ 12,   0,  45]],
#
#        [[ 20,  12,  27],
#         [ 18,  10,  25],
#         [ 12,   4,  19],
#         ...,
#         [ 16,   2,  50],
#         [ 20,   7,  53],
#         [ 21,   8,  54]],
#
#        [[ 21,  11,  31],
#         [ 21,  11,  31],
#         [ 19,   9,  29],
#         ...,
#         [ 30,  17,  63],
#         [ 34,  19,  62],
#         [ 37,  22,  65]],
#
#        ...,
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]],
#
#        [[180, 149, 111],
#         [180, 149, 111],
#         [180, 149, 111],
#         ...,
#         [174, 143, 105],
#         [174, 143, 105],
#         [174, 143, 105]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_videos/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.2144317626953125, 'inference': 12.266159057617188, 'postprocess': 1.329183578491211}]

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="hamC2hPywmRj4frv0kbV")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:03<00:00, 13127.64it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 5216.41it/s]

# %%
import shutil
shutil.move("tennis-ball-detection-6/train",
            "tennis-ball-detection-6/tennis-ball-detection-6/train",
            )
shutil.move("tennis-ball-detection-6/test",
            "tennis-ball-detection-6/tennis-ball-detection-6/test",
            )
shutil.move("tennis-ball-detection-6/valid",
            "tennis-ball-detection-6/tennis-ball-detection-6/valid",
            )
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=10 imgsz=640
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# engine/trainer: task=detect, mode=train, model=yolov5l6u.pt, data=/content/tennis-ball-detection-6/data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   3540480  ultralytics.nn.modules.conv.Conv             [512, 768, 3, 2]
#   8                  -1  3   5611008  ultralytics.nn.modules.block.C3              [768, 768, 3]
#   9                  -1  1   7079936  ultralytics.nn.modules.conv.Conv             [768, 1024, 3, 2]
#  10                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#  11                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  12                  -1  1    787968  ultralytics.nn.modules.conv.Conv             [1024, 768, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   6200832  ultralytics.nn.modules.block.C3              [1536, 768, 3, False]
#  16                  -1  1    394240  ultralytics.nn.modules.conv.Conv             [768, 512, 1, 1]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  20                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  21                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  22             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  24                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  25            [-1, 20]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  27                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  28            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  29                  -1  3   5807616  ultralytics.nn.modules.block.C3              [1024, 768, 3, False]
#  30                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  31            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  32                  -1  3  10496000  ultralytics.nn.modules.block.C3              [1536, 1024, 3, False]
#  33    [23, 26, 29, 32]  1   2601748  ultralytics.nn.modules.head.Detect           [1, [256, 512, 768, 1024]]
# YOLOv5l6u summary: 572 layers, 78,718,100 parameters, 78,718,084 gradients, 117.1 GFLOPs
#
# Transferred 843/947 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.33.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /content/tennis-ball-detection-6/tennis-ball-detection-6/train/labels.cache... 428 images, 2 backgrounds, 0 corrupt: 100% 428/428 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.17 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/tennis-ball-detection-6/tennis-ball-detection-6/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 155 weight(decay=0.0), 164 weight(decay=0.0005), 163 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      11.6G      3.567      53.01      1.036         12        640: 100% 27/27 [00:14<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  3.85it/s]
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      11.2G      3.453      22.97      1.025         12        640: 100% 27/27 [00:12<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.29it/s]
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      11.2G      3.548      14.01      1.026         12        640: 100% 27/27 [00:11<00:00,  2.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.32it/s]
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      11.2G      3.495      12.45      1.041         12        640: 100% 27/27 [00:11<00:00,  2.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.68it/s]
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      11.2G      3.418      8.591     0.9732         12        640: 100% 27/27 [00:11<00:00,  2.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  5.26it/s]
#                    all        100        101          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      11.5G      3.321      5.959     0.9417         12        640: 100% 27/27 [00:11<00:00,  2.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.40it/s]
#                    all        100        101      0.558      0.386      0.355     0.0758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      11.5G      3.009      4.383      0.936         11        640: 100% 27/27 [00:11<00:00,  2.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.47it/s]
#                    all        100        101      0.383      0.203       0.14     0.0257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      11.5G      3.027       4.35     0.9476         12        640: 100% 27/27 [00:11<00:00,  2.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.49it/s]
#                    all        100        101      0.592      0.257       0.24     0.0549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      11.2G      2.813      3.423     0.9249         12        640: 100% 27/27 [00:11<00:00,  2.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.50it/s]
#                    all        100        101      0.459      0.218      0.194     0.0515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      11.5G      2.711      3.288     0.8996         12        640: 100% 27/27 [00:11<00:00,  2.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:00<00:00,  4.43it/s]
#                    all        100        101      0.594      0.304      0.279     0.0808
#
# 10 epochs completed in 0.046 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 158.0MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 158.0MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# YOLOv5l6u summary (fused): 417 layers, 78,668,116 parameters, 0 gradients, 116.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:01<00:00,  3.36it/s]
#                    all        100        101      0.557      0.386      0.355     0.0751
# Speed: 0.1ms preprocess, 6.7ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
